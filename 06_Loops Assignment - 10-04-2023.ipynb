# %% [markdown]
# ### Write a Python program to find the length of the my_str using loop:-
# #### Input:- 'Write a Python program to find the length of the my_str'
# #### Output:- 55

# %%
my_str = "Write a Python program to find the length of the my_str"

# Using for loop

strlen_for = 0    # Variable to hold the string lenght

for i in my_str:     # Running the loop for each character in my_str  
    strlen_for += 1     # Incrementing the lenght value by one

print(f"The lenght of my_str is {strlen_for} characters (using for loop)")

# Using while loop

strlen_while = 0

while strlen_while < len(my_str):  # Running the loop when lenght variable is lesser than the total lenght  
    strlen_while += 1              # Incrementing the lenght value by one
    
print(f"The lenght of my_str is {strlen_while} characters (using while loop)")

# Using method

print(f"The lenght of my_str is {len(my_str)} characters (using builtin method)")

# Comprehension

# strlen_comp = 0

# (strlen_comp += 1) for i in my_str
# Out:
# The lenght of my_str is 55 characters (using for loop)
# The lenght of my_str is 55 characters (using while loop)
# The lenght of my_str is 55 characters (using builtin method)

# %% [markdown]
# ### Write a Python program to find the total number of times letter 'p' is appeared in the below string using loop:-
# #### Input:- 'peter piper picked a peck of pickled peppers.\n'
# #### Output:- 9

# %%
my_str2 = "peter piper picked a peck of pickled peppers.\n"

# Using for loop

count_p_for = 0    # Variable to count the occurance of 'p'

for i in my_str2:    # Running the loop for each character in my_str2  
    if i == 'p':    # Checking if the character is 'p'
        count_p_for += 1    # Incrementing the count
    
print(f"The letter 'p' has appeared {count_p_for} times in the given string (using for loop)")

# Using while loop

count_p_while = 0    # Variable to count the occurance of 'p'   

strlen = 0    # Variable to run the loop

while strlen < len(my_str2):    # Running the loop for the lenght of string
    if my_str2[strlen] == 'p':    # Checking if the character is 'p'
        count_p_while += 1     # Incrementing the count
    strlen += 1    # Incrementing to run the loop

print(f"The letter 'p' has appeared {count_p_while} times in the given string (using while loop)")

# Using count method

print(f"The letter 'p' has appeared {my_str2.count('p')} times in the given string (using builtin method)")
# Out:
# The letter 'p' has appeared 9 times in the given string (using for loop)
# The letter 'p' has appeared 9 times in the given string (using while loop)
# The letter 'p' has appeared 9 times in the given string (using builtin method)

# %% [markdown]
# ### Write a Python Program, to print all the indexes of all occurences of letter 'p' appeared in the string using loop:-
# #### Input:- 'peter piper picked a peck of pickled peppers.'
# #### Output:-
# 0
# 6
# 8
# 12
# 21
# 29
# 37
# 39
# 40

# %%
my_str2 = "peter piper picked a peck of pickled peppers.\n"

# Using for loop

strindex = 0    # Variable to hold the index while looping

print("Using for loop")

for i in my_str2:    # Running the loop for each character in my_str2  
    if i == 'p':    # Checking if the character is 'p'
        print(strindex)    # Printing the index
    strindex += 1

# Using while loop

strlen = 0    # Variable to run the loop

print("\nUsing while loop")

while strlen < len(my_str2):    # Running the loop for the lenght of string
    if my_str2[strlen] == 'p':    # Checking if the character is 'p'
        print(strlen)     # Printing the index
    strlen += 1    # Incrementing to run the loop

# Using alternate method

strlen2 = 0    # Variable for looping

strindex2 = my_str2.find('p')    # Storing the first index of 'p' in a variable
print(f"\nUsing an alternate method\n{strindex2}")

while strlen2 < len(new_str):    # Looping over the sliced string
    new_str = my_str2[strindex2+1:]    # Slicing the string from the alphabet after 'p'
    strindex2 = strindex2+1+new_str.find('p')    # Since we are strating the new string from the alphabet after previous index
    print(strindex2)
    strlen2 += 1
# Out:
# Using for loop
# 0
# 6
# 8
# 12
# 21
# 29
# 37
# 39
# 40
#
# Using while loop
# 0
# 6
# 8
# 12
# 21
# 29
# 37
# 39
# 40
#
# Using an alternate method
# 0
# 6
# 8
# 12
# 21
# 29
# 37
# 39
# 40

# %% [markdown]
# ### Write a python program to find below output using loop:-
# #### Input:- 'peter piper picked a peck of pickled peppers.'
# #### Output:- [ 'peter' , 'piper' , 'picked' , 'a' , 'peck' , 'of' , 'pickled' ,'peppers' ]

# %%
my_str3 = 'peter piper picked a peck of pickled peppers.'

# Using for loop over the string

space_index_start = 0    # Variable to store the index of first occurance of space
space_index_end = 0    # Variable to store the index of next occurance of space/full stop
out1 = []    # Output list

for i in my_str3:    # Looping over string
    if i == ' ' or i == '.':    # Checking if the character is space or full stop
        new_str2 = my_str3[space_index_start:space_index_end]    # New temporary string sling the actual string in between spaces
        out1.append(new_str2)    # Appending the new string to output list
        space_index_start = space_index_end+1    # Strating the refernece to test the string after the previous slice
    space_index_end += 1    # Incrementing the index with respect to the looping string

print(f"Using for loop over the string : {out1}")

# Using for loop over the range

out2 = []    # Output list
j = 0    # Variable to store the index of space

for i in range(len(my_str3)):    # Looping over the range
    if my_str3[i] == ' ' or my_str3[i] == '.':
        new_str3 = my_str3[j:i]
        out2.append(new_str3)
        j = i + 1
    i += 1

print(f"Using for loop over the range : {out2}")

#Using for loop without amend function

out3 = [] 

space_index_start2 = 0    
space_index_end2 = 0    

for i in my_str3:    
    if i == ' ' or i == '.':    
        new_str2 = my_str3[space_index_start2:space_index_end2]    
        out3 += [new_str2]    # Adding the list of new string to existing list
        space_index_start2 = space_index_end2+1    
    space_index_end2 += 1    

print(f"Using for loop without amend : {out3}")

#Using while loop

out4 = []

space_index_start3 = 0    
space_index_end3 = 0 

while space_index_end3 < len(my_str3):
    if my_str3[space_index_end3] == ' ' or my_str3[space_index_end3] == '.':
        new_str3 = my_str3[space_index_start3:space_index_end3]    
        out4 += [new_str3]    # Adding the list of new string to existing list
        space_index_start3 = space_index_end3+1    
    space_index_end3 += 1 

print(f"Using while loop : {out4}")

#Using builtin methods

if my_str3[-1] == '.':
    my_str4 = my_str3[:-1]
else:
    my_str4 = my_str3

out5 = my_str4.split()
print(f"Using builtin method : {out5}")
# Out:
# Using for loop over the string : ['peter', 'piper', 'picked', 'a', 'peck', 'of', 'pickled', 'peppers']
# Using for loop over the range : ['peter', 'piper', 'picked', 'a', 'peck', 'of', 'pickled', 'peppers']
# Using for loop without amend : ['peter', 'piper', 'picked', 'a', 'peck', 'of', 'pickled', 'peppers']
# Using while loop : ['peter', 'piper', 'picked', 'a', 'peck', 'of', 'pickled', 'peppers']
# Using builtin method : ['peter', 'piper', 'picked', 'a', 'peck', 'of', 'pickled', 'peppers']

# %% [markdown]
# ### Write a python program to find below output using loop:-
# #### Input:- 'peter piper picked a peck of pickled peppers.'
# #### Output:- 'peppers pickled of peck a picked piper peter'

# %%
my_str3 = 'peter piper picked a peck of pickled peppers.'

# Using for loop

space_index_start4 = 0    # Variable to store the index of first occurance of space
space_index_end4 = 0    # Variable to store the index of next occurance of space/full stop
out6 = []    # Output list

for i in my_str3:    # Looping over string
    if i == ' ' or i == '.':    # Checking if the character is space or full stop
        new_str4 = my_str3[space_index_start4:space_index_end4]    # New temporary string slicing the actual string in between spaces
        out6 += [new_str4]    # Appending the new string to output list
        space_index_start4 = space_index_end4+1    # Strating the refernece to test the string after the previous slice
    space_index_end4 += 1    # Incrementing the index with respect to the looping string

out6_reversed = out6[::-1]    # Reversing the list of words in string
out_string = ""    # Empty string to store output

for i in out6_reversed:    # Looping over the list of sliced words
    out_string = out_string + i + " "    # Concarting as string
    
print(f"Using for loop over the string : {out_string}")


# Using while loop

space_index_start5 = 0    
space_index_end5 = 0 
out7 = []

while space_index_end5 < len(my_str3):    # Running while loop for all elements of the string
    if my_str3[space_index_end5] == ' ' or my_str3[space_index_end5] == '.':
        new_str5 = my_str3[space_index_start5:space_index_end5]    # Slicing based on space
        out7 += [new_str5]    # Adding the list of new string to existing list
        space_index_start5 = space_index_end5+1    # Setting the indexof new string a the next element of previos last element  
    space_index_end5 += 1    # Incrementing loop variable
    
out7_reversed = out7[::-1]    # Reversing the list of words in string
out_string2 = ""    # Empty string to store output
i = 0

while i < len(out7_reversed):    # Looping over the list of sliced words
    out_string2 = out_string2 + out7_reversed[i] + " "    # Concarting as string
    i += 1
    
print(f"Using while loop : {out_string2}")
# Out:
# Using for loop over the string : peppers pickled of peck a picked piper peter
# Using while loop : peppers pickled of peck a picked piper peter

# %% [markdown]
# ### Write a python program to find below output using loop:-
# #### Input:- 'peter piper picked a peck of pickled peppers.'
# #### Output:- '.sreppep delkcip fo kcep a dekcip repip retep'

# %%
my_str3 = "peter piper picked a peck of pickled peppers."

#Using for loop

out_string3 = ""    # To store output string
len_my_str3 = 0    # Variable to count the lenght of the string

for i in my_str3:    # Loop to find the lenght of string
    len_my_str3 += 1    # Incrementing the lenght for each element in string

for j in range(len_my_str3):    # Looping with interger over the lenght of string
    out_string3 = out_string3 + my_str3[len_my_str3 - 1 - j]    # Concarting the output string in reverse order of input
    
print(f"Using for loop : {out_string3}")

# Using while loop

out_string4 = ""    # To store output string
len_my_str3_while = 0    # Variable to count the lenght of the string

while my_str3[len_my_str3_while:]:    # Loop to find the lenght of string condition returns true for sliced string if not empty
    len_my_str3_while += 1    # Counting the lenght
    
k = 0
    
while k < len_my_str3_while:    # Looping over the lenght of string
    out_string4 = out_string4 + my_str3[len_my_str3_while - 1 - k]    # Concarting the output string in reverse order of input
    k += 1

print(f"Using while loop : {out_string4}")

# Using slicing

print(f"Using slicing : {my_str3[::-1]}")
# Out:
# Using for loop : .sreppep delkcip fo kcep a dekcip repip retep
# Using while loop : .sreppep delkcip fo kcep a dekcip repip retep
# Using slicing : .sreppep delkcip fo kcep a dekcip repip retep

# %% [markdown]
# ### Write a python program to find below output using loop:-
# #### Input:- 'peter piper picked a peck of pickled peppers.'
# #### Output:- 'retep repip dekcip a kcep fo delkcip sreppep'

# %%
my_str3 = 'peter piper picked a peck of pickled peppers.'

# Using for loop

space_index_start6 = 0    # Variable to store the index of first occurance of space
space_index_end6 = 0    # Variable to store the index of next occurance of space/full stop
out_string6 = ""    # Output list

for i in my_str3:    # Looping over string
    if i == ' ' or i == '.':    # Checking if the character is space or full stop
        new_str6 = my_str3[space_index_start6:space_index_end6]    # New temporary string slicing the actual string in between spaces
        out_string6 = out_string6 + new_str6[::-1] + " "   # Concarting the string with reversed characters
        space_index_start6 = space_index_end6 + 1    # Strating the refernece to test the string after the previous slice
    space_index_end6 += 1    # Incrementing the index with respect to the looping string
    
print(f"Using for loop : {out_string6}")

# Using while loop

space_index_start7 = 0    
space_index_end7 = 0 
out_string7 = ""

while space_index_end7 < len(my_str3):    # Running while loop for all elements of the string
    if my_str3[space_index_end7] == ' ' or my_str3[space_index_end7] == '.':
        new_str7 = my_str3[space_index_start7:space_index_end7]    # Slicing based on space
        out_string7 = out_string7 + new_str7[::-1] + " "    # Concarting the string with reversed characters
        space_index_start7 = space_index_end7 + 1    # Setting the indexof new string a the next element of previos last element  
    space_index_end7 += 1    # Incrementing loop variable
        
print(f"Using while loop : {out_string7}")
# Out:
# Using for loop : retep repip dekcip a kcep fo delkcip sreppep
# Using while loop : retep repip dekcip a kcep fo delkcip sreppep

# %% [markdown]
# ### Write a python program to find below output using loop:-
# #### Input:- 'peter piper picked a peck of pickled peppers.'
# #### Output:- 'Peter Piper Picked A Peck Of Pickled Peppers'

# %%
my_str3 = "peter piper picked a peck of pickled peppers."

# Using for loop

out_string8 = ""    # Variable to store the output string
space_index_start8 = 0    # Variable to store the index of the first alphabet after space
space_index_end8 = 0    # Variable to store the index of the last alphabet before space
temp_list = []    # Temporary list to hold the string as list

diff = ord('a') - ord('A')    # Finding the difference between an upper and a lower case alphabet

for i in my_str3:    # Looping over string
    if i != '.':
        temp_list.append(i)    # Converting the string into a list withput the last full stop
    
    if i == ' ' or i == '.':    # Checking if the character is space or full stop
        # print(chr(ord(temp_list[space_index_start8])))    # To check if the logic is fetching correct alphabet
        temp_list[space_index_start8] = chr(ord(temp_list[space_index_start8]) - diff)    # Making the first letter of the string upper case
        space_index_start8 = space_index_end8 + 1    # Strating the refernece to test the string after space
    
    space_index_end8 += 1    # Incrementing the index with respect to the looping string

for j in temp_list:
    out_string8 += j    # Coverting the list back to string
        
# print(temp_list)
print(f"Using for loop over the string : {out_string8}")

# Using while loop

out_string9 = ""
space_index_start9 = 0
space_index_end9 = 0
temp_list2 = []

while space_index_end9 < len(my_str3):
    # print(my_str3[space_index_end9])
    
    if my_str3[space_index_end9] != '.':
        temp_list2.append(my_str3[space_index_end9])
            
    if my_str3[space_index_end9] == ' ' or my_str3[space_index_end9] == '.':
        # print(my_str3[space_index_start9])
        temp_list2[space_index_start9] = chr(ord(temp_list2[space_index_start9]) - diff)
        # print(temp_list2[space_index_start9])
        space_index_start9 = space_index_end9 + 1
    space_index_end9 += 1
    
# print(temp_list2)

j = 0

while j < len(temp_list2):
    out_string9 += temp_list2[j] 
    j  += 1

print(f"Using while loop over the string : {out_string9}")

# Using builtin method

print(f"Using builtin method : {my_str3.title()}")
# Out:
# Using for loop over the string : Peter Piper Picked A Peck Of Pickled Peppers
# Using while loop over the string : Peter Piper Picked A Peck Of Pickled Peppers
# Using builtin method : Peter Piper Picked A Peck Of Pickled Peppers.

# %% [markdown]
# ### Write a python program to implement index method using loop. If sub_str is found in my_str then it will print the index of first occurrence of first character of matching string in my_str:-
# #### Input:- my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.' ,
# ##### sub_str = 'Pickl'
# ##### Output:- 29

# %%
my_str4 = "Peter Piper Picked A Peck Of Pickled Peppers."
search = input("Enter a sub-string to search : ")
str_index_list_for = []    # List to hold the idices of reference of the first alphabet in search
str_index_list_while = []

# Using for loop 

if len(search) < 2:    # Prompting to enter string atleast 2 characters long
    print("Sub-string too short (enter atleast 2 aphabets) - for loop")

elif len(search) >=2 and len(search) <= len(my_str4):    # Checking if the entered string is more than 2 and less than total lenght of actual string
    str_index1 = 0    # Variable to hold the index of the first character in search string
    for i in my_str4:
        if search[0] == i:    # Checking the instances where first characetr is present in the string
            str_index_list_for.append(str_index1)    # Adding the indices in a list
        str_index1 += 1 
    
    for j in str_index_list_for:    # Looping over the indices list
        temp_str = my_str4[j:(j+len(search))]    # Creating a temporary string sliced for each value of the list
        if temp_str == search:    # Checking if the search string is same as sliced string
            print(f"Using for loop : Index of the first occurance of '{search}' is in {j}")
            break    # Exit the loop as soon the search term is found for the first time
        
    if temp_str != search:    # If the string is not found
        print("Not Found - for loop")

else:
    print("Input too long")
    
# Using while loop

if len(search) < 2:    # Prompting to enter string atleast 2 characters long
    print("Sub-string too short (enter atleast 2 aphabets) - while loop")

elif len(search) >=2 and len(search) <= len(my_str4):    # Checking if the entered string is more than 2 and less than total lenght of actual string
    str_index2 = 0    # Variable to hold the index of the first character in search string
    
    while str_index2 < len(my_str4):
        if search[0] == my_str4[str_index2]:    # Checking the instances where first characetr is present in the string
            str_index_list_while.append(str_index2)    # Adding the indices in a list
        str_index2 += 1 
    
    str_index3 = 0    # Variable to loop over the list
    
    while str_index3 < len(str_index_list_while):    # Looping over the indices list
        temp_str_while = my_str4[str_index3:(str_index3+len(search))]    # Creating a temporary string sliced for each value of the list
        if temp_str == search:    # Checking if the search string is same as sliced string
            print(f"Using while loop : Index of the first occurance of '{search}' is in {j}")
            break    # Exit the loop as soon the search term is found for the first time
        str_index3 += 1
        
    if temp_str != search:    # If the string is not found
        print("Not Found - while loop")
        
else:
    print("Input too long - while loop")

# Using builtin method

if len(search) < 2:    # Prompting to enter string atleast 2 characters long
    print("Sub-string too short (enter atleast 2 aphabets) - while loop")

elif len(search) >=2 and len(search) <= len(my_str4):    # Checking if the entered string is more than 2 and less than total lenght of actual string
    print(f"Using builtin method : Index of the first occurance of '{search}' is in {my_str4.find(search)}")
    
else:
    print("Input too long - while loop")
# Out:
# Enter a sub-string to search : Pickl
# Using for loop : Index of the first occurance of 'Pickl' is in 29
# Using while loop : Index of the first occurance of 'Pickl' is in 29
# Using builtin method : Index of the first occurance of 'Pickl' is in 29

# %% [markdown]
# ### Write a python program to implement replace method using loop. If sub_str is found in my_str then it will replace the first occurrence of sub_str with new_str else it will will print sub_str not found:-
# #### Input:- my_str = 'Peter Piper Picked A Peck Of Pickled Peppers.' ,
# #### sub_str = 'Peck' , new_str = 'Pack'
# #### Output:- 'Peter Piper Picked A Pack Of Pickled Peppers.'

# %%
my_str4 = "Peter Piper Picked A Peck Of Pickled Peppers."
search2 = input("Enter a sub-string to search : ")
replace = input("Enter a sub-string to replace : ")
str_index_list_for2 = []
str_index_list_while2 = []

# Using for loop

if len(search2) < 2:    # Prompting to enter string atleast 2 characters long
    print("Sub-string too short (enter atleast 2 aphabets) - for loop")

elif len(search2) >=2 and len(search2) <= len(my_str4):    # Checking if the entered string is more than 2 and less than total lenght of actual string
    str_index3 = 0    # Variable to hold the index of the first character in search string
    
    for i in my_str4:
        if search2[0] == i:    # Checking the instances where first characetr is present in the string
            str_index_list_for2.append(str_index3)    # Adding the indices in a list
        str_index3 += 1 
    
    for j in str_index_list_for2:    # Looping over the indices list
        temp_str = my_str4[j:(j + len(search2))]    # Creating a temporary string sliced for each value of the list
        if temp_str == search2:    # Checking if the search string is same as sliced string            
            my_str_list = []    # List to hold the string, coverted as list
            out_str = ""    # Variable to hold the output string
        
            for k in my_str4:    # Loop to covert the string into list for changing the sub string
                my_str_list.append(k)
        
            for l in replace:    # Loop for replacing the substring
                my_str_list[j] = l    # Starting to change the main string with the first reference of the sub string
                j += 1
        
            for m in my_str_list:    # Converting the list back to string
                out_str += m
        
            print(f"Using for loop - {out_str}")
            
            break    # Exit the loop as soon the search term is found for the first time
                    
    if temp_str != search2:    # If the string is not found
        print(f"{search2} - Not Found - for loop")

else:
    print("Input too long - for loop")

# Using while loop

if len(search2) < 2:    # Prompting to enter string atleast 2 characters long
    print("Sub-string too short (enter atleast 2 aphabets) - while loop")

elif len(search2) >=2 and len(search2) <= len(my_str4):    # Checking if the entered string is more than 2 and less than total lenght of actual string
    str_index4 = 0    # Variable to hold the index of the first character in search string
    
    while str_index4 < len(my_str4):
        if search2[0] == my_str4[str_index4]:    # Checking the instances where first characetr is present in the string
            str_index_list_while2.append(str_index4)    # Adding the indices in a list
        str_index4 += 1 
    
    n = 0    # Loop variable
    
    while n < len(str_index_list_while2):    # Looping over the indices list
        temp_str2 = my_str4[str_index_list_while2[n]:(str_index_list_while2[n] + len(search2))]    # Creating a temporary string sliced for each value of the list
        if temp_str2 == search2:    # Checking if the search string is same as sliced string            
            my_str_list2 = []    # List to hold the string, coverted as list
            out_str2 = ""    # Variable to hold the output string
        
            o = 0    # Loop varables for covertinglist to string and back after replacing
            p = 0
            q = 0
            r = 0
            
            while o < len(my_str4):    # Loop to covert the string into list for changing the sub string
                my_str_list2.append(my_str4[o])
                o += 1
        
            while p < len(replace):    # Loop for replacing the substring
                my_str_list2[str_index_list_while2[n] + r] = replace[p]    # Starting to change the main string with the first reference of the sub string
                r += 1
                p += 1
        
            while q < len(my_str_list2):    # Converting the list back to string
                out_str2 += my_str_list2[q]
                q += 1
        
            print(f"Using while loop - {out_str2}")
            
            break    # Exit the loop as soon the search term is found for the first time
        
        n += 1 # Incrementing the loop variable
        
    if temp_str2 != search2:    # If the string is not found
        print(f"{search2} - Not Found - while loop")

else:
    print("Input too long - while loop")
    
# Using builtin method

if len(search2) < 2:    # Prompting to enter string atleast 2 characters long
    print("Sub-string too short (enter atleast 2 aphabets) - builtin method")

elif len(search2) >=2 and len(search2) <= len(my_str4):    # Checking if the entered string is more than 2 and less than total lenght of actual string
    if search2 in my_str4:
        print(f"Using builtin method - {my_str4.replace(search2,replace)}")
    
    else:
        print(f"{search2} - Not Found - builtin method")
            
else:
    print("Input too long - builtin method")
# Out:
# Enter a sub-string to search : Peck
# Enter a sub-string to replace : Pack
# Using for loop - Peter Piper Picked A Pack Of Pickled Peppers.
# Using while loop - Peter Piper Picked A Pack Of Pickled Peppers.
# Using builtin method - Peter Piper Picked A Pack Of Pickled Peppers.

# %% [markdown]
# ### Q. Write a python program to find below output (implements rjust and ljust) using loop:-
# #### Input:- 'Peter Piper Picked A Peck Of Pickled Peppers.' , sub_str = 'Peck' ,
# #### Output:- '*********************Peck********************'

# %%
my_str4 = "Peter Piper Picked A Peck Of Pickled Peppers."
search3 = input("Enter a sub-string to implement just : ")
# search3 = 'Peck'

# Using for loop

str_index_list_for3 = []

if len(search3) < 2:    # Prompting to enter string atleast 2 characters long
    print("Sub-string too short (enter atleast 2 aphabets) - for loop")

elif len(search3) >=2 and len(search3) <= len(my_str4):    # Checking if the entered string is more than 2 and less than total lenght of actual string
    str_index5 = 0    # Variable to hold the index of the first character in search string
    for i in my_str4:
        if search3[0] == i:    # Checking the instances where first characetr is present in the string
            str_index_list_for3.append(str_index5)    # Adding the indices in a list
        str_index5 += 1 
    
    for j in str_index_list_for3:    # Looping over the indices list
        temp_str = my_str4[j:(j + len(search3))]    # Creating a temporary string sliced for each value of the list
        if temp_str == search3:    # Checking if the search string is same as sliced string
            first_occ = j    # Storing the first occurance of the search expression in a variable
            break    # Exit the loop as soon the search term is found for the first time
        
    if temp_str == search3:
        my_str_list3 = []    # List to hold the coverted output
        out_string3 = ""    # Variable for output string
        out_string3v2 = search3    # Variable to perform ljust and rjust with word only
    
        for k in my_str4:    # Looping to create a list with string 
            my_str_list3.append(k)
            if len(out_string3v2) < len(my_str4) - first_occ:    # Performing ljust function 
                out_string3v2 = out_string3v2 + '*'
            elif len(out_string3v2) < len(my_str4):    # Performing rjust function 
                out_string3v2 = '*' + out_string3v2
    
        my_str_list3 = ['*' if l < first_occ or l > first_occ + len(search3) - 1 else my_str_list3[l] for l in range(len(my_str_list3))]
        # Using list comprehension to make the charcater as '*' before the search sub string
    
        for m in my_str_list3:    # Looping to create a string from the list
            out_string3 += m
    
        print(f"Using for loop (method 1) : {out_string3}")
        print(f"Using for loop (method 2) : {out_string3v2}")
        
    if temp_str != search3:    # If the string is not found
        print("Not Found - for loop")

else:
    print("Input too long - for loop")

# Using while loop

str_index_list_while3 = []

if len(search3) < 2:    # Prompting to enter string atleast 2 characters long
    print("Sub-string too short (enter atleast 2 aphabets) - while loop")

elif len(search3) >=2 and len(search3) <= len(my_str4):    # Checking if the entered string is more than 2 and less than total lenght of actual string
    str_index6 = 0    # Variable to hold the index of the first character in search string
    
    while str_index6 < len(my_str4):
        if search3[0] == my_str4[str_index6]:    # Checking the instances where first characetr is present in the string
            str_index_list_while3.append(str_index6)    # Adding the indices in a list
        str_index6 += 1 
    
    n = 0
    o = 0
    p = 0
    q = 0
    first_occ_while = 0
    
    while n < len(str_index_list_while3):    # Looping over the indices list
        temp_str = my_str4[str_index_list_while3[n]:(str_index_list_while3[n] + len(search3))]    # Creating a temporary string sliced for each value of the list
        if temp_str == search3:    # Checking if the search string is same as sliced string
            first_occ_while = str_index_list_while3[n]    # Storing the first occurance of the search expression in a variable
            break    # Exit the loop as soon the search term is found for the first time
        n += 1
        
    if temp_str == search3:
        my_str_list4 = []    # List to hold the coverted output
        out_string4 = ""    # Variable for output string
        out_string4v2 = search3    # Variable to perform functions using word only
    
        while o < len(my_str4):    # Looping to create a list with string 
            my_str_list4.append(my_str4[o])
            if len(out_string4v2) < len(my_str4) - first_occ:    # Performing ljust function 
                out_string4v2 = out_string4v2 + '*'
            elif len(out_string4v2) < len(my_str4):    # Performing rjust function 
                out_string4v2 = '*' + out_string4v2
            o += 1
    
        while p < len(my_str_list4):    # Looping to change all the elements except sub string to '*'
            if p < first_occ_while or p > first_occ_while + len(search3) - 1:
                my_str_list4[p] = '*'
            p += 1
     
        while q < len(my_str_list4):    # Looping to create a string from the list
            out_string4 += my_str_list4[q]
            q += 1
    
        print(f"Using while loop (method 1) : {out_string4}")
        print(f"Using while loop (method 2) : {out_string4v2}")
        
    if temp_str != search3:    # If the string is not found
        print("Not Found - while loop")

else:
    print("Input too long - while loop")

# Using builtin method

if len(search3) < 2:    # Prompting to enter string atleast 2 characters long
    print("Sub-string too short (enter atleast 2 aphabets) - builtin functions")

elif len(search3) >=2 and len(search3) <= len(my_str4):    # Checking if the entered string is more than 2 and less than total lenght of actual string
    if search3 in my_str4:
        out_string5 = search3.ljust(len(my_str4) - my_str4.find(search3),'*')
        out_string5 = out_string5.rjust(len(my_str4),'*')
        print(f"Using builtin functions : {out_string5}")
        
    else:    # If the string is not found
        print("Not Found - builtin functions")

else:
    print("Input too long -  builtin functions")
# Out:
# Enter a sub-string to implement just : Peck
# Using for loop (method 1) : *********************Peck********************
# Using for loop (method 2) : *********************Peck********************
# Using while loop (method 1) : *********************Peck********************
# Using while loop (method 2) : *********************Peck********************
# Using builtin functions : *********************Peck********************

# %% [markdown]
# ### Write a python program to find below output using loop:-
# #### Input:- 'This is Python class' , sep = ' is' ,
# #### Output:- [ 'This' , 'is' , 'Python class' ]

# %%
my_str5 = "This is Python class"
sep = input("Enter the seperator : ") 
# sep = "is"

# Using for loop

if len(sep) < 2:
    print("Separator too short - for loop")

elif len(sep) >= 2 and len(sep) < len(my_str5):
    index_start = 0    # Variable to hold the start of the string to be added in output 
    index_end = 0    # Variable to hold the end of the string to be added in output 
    sep_out_list_for = []    # Output list

    for i in my_str5:    # Looping over the input string
        if index_end == 0:    # Blocck to check if the first word is our seperator
            temp_str = my_str5[index_end : len(sep)]
            
            if temp_str == sep:    # Checking if thefirst word is the seperator
                append_str = temp_str
                sep_out_list_for.append(append_str)
                index_start = index_end + len(sep) + 1    # Changing the start of the new word to the next character
                
        elif i == " ":    # Checking for the word after space
            temp_str = my_str5[index_end + 1 : index_end + len(sep) + 1]
            
            if temp_str == sep:
                append_str = my_str5[index_start : index_end]    # Holding the string in variable till the next space
                sep_out_list_for.append(append_str)
                sep_out_list_for.append(temp_str)
                index_start = index_end + len(sep) + 1    # Changing the start of the new word to the next character
            
        elif index_end == len(my_str5) - 1:    # If reached the final character without finding the seperator
            append_str = my_str5[index_start + 1 : index_end + 1]    # Adding the word from previous seperator till the end
            sep_out_list_for.append(append_str)

        index_end += 1
        
    print(f"Using for loop : {sep_out_list_for}")

else:
    print("Input too long - for loop")

# Using builtin method
        
out_sep = my_str5.split(" ", 2)

print(f"Using builtin methods : {out_sep}")
# Out:
# Enter the seperator : is
# Using for loop : ['This', 'is', 'Python class']
# Using builtin methods : ['This', 'is', 'Python class']
